# %% [markdown]
# # 1. Imports

# %%
import numpy as np
import pandas as pd
import math
import torch
import torch.nn.functional as F

# %% [markdown]
# # 2. Data

# %%
train = pd.read_csv('train.csv')
train
# Out:
#        userId  movieId                          title  \
# 0           1        1               Toy Story (1995)
# 1           1        3        Grumpier Old Men (1995)
# 2           1        6                    Heat (1995)
# 3           1       47    Seven (a.k.a. Se7en) (1995)
# 4           1       50     Usual Suspects, The (1995)
# ...       ...      ...                            ...
# 80659     610   164179                 Arrival (2016)
# 80660     610   166534                   Split (2017)
# 80661     610   168248  John Wick: Chapter Two (2017)
# 80662     610   168250                 Get Out (2017)
# 80663     610   168252                   Logan (2017)
#
#                                             genres  year  rating
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995     4.0
# 1                                   Comedy|Romance  1995     4.0
# 2                            Action|Crime|Thriller  1995     4.0
# 3                                 Mystery|Thriller  1995     5.0
# 4                           Crime|Mystery|Thriller  1995     5.0
# ...                                            ...   ...     ...
# 80659                                       Sci-Fi  2016     5.0
# 80660                        Drama|Horror|Thriller  2017     4.0
# 80661                        Action|Crime|Thriller  2017     5.0
# 80662                                       Horror  2017     5.0
# 80663                                Action|Sci-Fi  2017     5.0
#
# [80664 rows x 6 columns]

# %%
test = pd.read_csv('test.csv')
test
# Out:
#          rId  userId  movieId                                title  \
# 0          1       1      151                       Rob Roy (1995)
# 1          2       1      423                    Blown Away (1994)
# 2          3       1      596                     Pinocchio (1940)
# 3          4       1      673                     Space Jam (1996)
# 4          5       1     1029                         Dumbo (1941)
# ...      ...     ...      ...                                  ...
# 20161  20162     610   156371          Everybody Wants Some (2016)
# 20162  20163     610   160836                        Hazard (2005)
# 20163  20164     610   163937                   Blair Witch (2016)
# 20164  20165     610   166528  Rogue One: A Star Wars Story (2016)
# 20165  20166     610   170875       The Fate of the Furious (2017)
#
#                                                   genres  year
# 0                               Action|Drama|Romance|War  1995
# 1                                        Action|Thriller  1994
# 2                       Animation|Children|Fantasy|Music  1940
# 3      Adventure|Animation|Children|Comedy|Fantasy|Sc...  1996
# 4                         Animation|Children|Drama|Music  1941
# ...                                                  ...   ...
# 20161                                             Comedy  2016
# 20162                              Action|Drama|Thriller  2005
# 20163                                    Horror|Thriller  2016
# 20164                    Action|Adventure|Fantasy|Sci-Fi  2016
# 20165                        Action|Crime|Drama|Thriller  2017
#
# [20166 rows x 6 columns]

# %%
submission = pd.read_csv('submission.csv')
submission
# Out:
#          rId  rating
# 0          1     3.0
# 1          2     3.0
# 2          3     1.0
# 3          4     4.0
# 4          5     1.0
# ...      ...     ...
# 20161  20162     2.0
# 20162  20163     2.0
# 20163  20164     1.0
# 20164  20165     1.0
# 20165  20166     2.0
#
# [20166 rows x 2 columns]

# %% [markdown]
# # 3. Latent Factor Models

# %% [markdown]
# ### A. 피봇 테이블(Rating)

# %%
###---rating matrix---###
df = pd.pivot_table(train, 
                index = 'userId',
                columns = 'title',
                values = 'rating',
                )
df
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# ...            ...                                      ...
# 606            NaN                                      NaN
# 607            NaN                                      NaN
# 608            NaN                                      NaN
# 609            NaN                                      NaN
# 610            4.0                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# ...                        ...                  ...
# 606                        NaN                  NaN
# 607                        NaN                  NaN
# 608                        NaN                  NaN
# 609                        NaN                  NaN
# 610                        NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# ...                           ...                              ...
# 606                           NaN                              NaN
# 607                           NaN                              NaN
# 608                           NaN                              NaN
# 609                           NaN                              NaN
# 610                           NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# ...                    ...                   ...                          ...
# 606                    NaN                   NaN                          NaN
# 607                    NaN                   NaN                          NaN
# 608                    NaN                   NaN                          NaN
# 609                    NaN                   NaN                          NaN
# 610                    NaN                   NaN                          3.5
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                  NaN  ...          NaN           NaN
# 2                                  NaN  ...          NaN           NaN
# 3                                  NaN  ...          NaN           NaN
# 4                                  NaN  ...          NaN           NaN
# 5                                  NaN  ...          NaN           NaN
# ...                                ...  ...          ...           ...
# 606                                NaN  ...          NaN           NaN
# 607                                NaN  ...          NaN           NaN
# 608                                NaN  ...          NaN           NaN
# 609                                NaN  ...          NaN           NaN
# 610                                NaN  ...          NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
# ...               ...                      ...
# 606               NaN                      NaN
# 607               NaN                      NaN
# 608               NaN                      NaN
# 609               NaN                      NaN
# 610               3.5                      3.0
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 606                                                   NaN
# 607                                                   NaN
# 608                                                   NaN
# 609                                                   NaN
# 610                                                   NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
# ...                 ...         ...                             ...
# 606                 NaN         NaN                             NaN
# 607                 NaN         NaN                             NaN
# 608                 4.5         NaN                             NaN
# 609                 NaN         NaN                             NaN
# 610                 NaN         2.0                             1.5
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
# ...                       ...                                        ...
# 606                       NaN                                        NaN
# 607                       NaN                                        NaN
# 608                       NaN                                        NaN
# 609                       NaN                                        NaN
# 610                       NaN                                        NaN
#
# [610 rows x 8949 columns]

# %% [markdown]
# items = torch.LongTensor(train['movieId'])
# users = torch.LongTensor(train['userId'])
# ratings = torch.FloatTensor(train['rating'])

# %% [markdown]
# ### B. 행렬 Q, P 생성

# %%
rows = len(df.index) 
cols = len(df.columns)

# %%
rank = 10
torch.manual_seed(1004)
Q = torch.randn(rows, rank, requires_grad=True)
P = torch.randn(cols, rank, requires_grad=True)

# %%
print(Q)
print(P)
# Out:
# tensor([[-1.6492, -0.6707, -0.6212,  ...,  1.2595,  2.0986, -0.7325],
#         [-0.4736,  1.5456,  0.4469,  ...,  0.9243,  0.9278,  1.1756],
#         [-0.0299,  1.3536, -0.0226,  ...,  0.6097,  1.4900,  0.7166],
#         ...,
#         [ 1.4390, -1.0777, -0.4058,  ..., -0.1690,  0.1073, -1.1088],
#         [-1.0472, -0.4021, -0.1893,  ..., -0.1600,  1.2254,  0.2835],
#         [-0.5060, -0.2514, -0.6829,  ...,  2.1894,  0.7369,  1.1160]],
#        requires_grad=True)
# tensor([[-0.1345, -0.1736, -1.4496,  ..., -0.8859, -1.2192, -0.5634],
#         [ 0.7533, -1.1351,  1.7105,  ...,  1.2544,  0.5263,  0.1503],
#         [-0.4316,  0.8055, -1.2533,  ..., -0.6397,  1.2673, -0.4306],
#         ...,
#         [ 0.3220,  1.1608,  1.0605,  ..., -1.0948, -0.0840,  0.4576],
#         [-0.2656, -0.4379,  1.3833,  ..., -0.0790, -1.3909, -0.5975],
#         [-0.4016, -1.2454, -0.4065,  ..., -0.8786,  0.6180, -0.2364]],
#        requires_grad=True)

# %% [markdown]
# ### C. 값이 있는 행렬 저장

# %%
## 값이 있는 행렬
value = []
for i in range(rows):
    for j in range(cols):
        if df.iloc[i, j] >= 0:
            # i : 행, j : 열, df.iloc : rating 값
            value.append((i, j, df.iloc[i, j]))

# %%
value
# Out:
# [(0, 45, 4.0),
#  (0, 184, 4.0),
#  (0, 227, 5.0),
#  (0, 303, 5.0),
#  (0, 372, 5.0),
#  (0, 407, 5.0),
#  (0, 520, 4.0),
#  (0, 623, 5.0),
#  (0, 688, 5.0),
#  (0, 690, 4.0),
#  (0, 727, 5.0),
#  (0, 765, 5.0),
#  (0, 774, 4.0),
#  (0, 778, 3.0),
#  (0, 850, 5.0),
#  (0, 858, 4.0),
#  (0, 878, 4.0),
#  (0, 910, 4.0),
#  (0, 963, 5.0),
#  (0, 994, 5.0),
#  (0, 1016, 5.0),
#  (0, 1124, 5.0),
#  (0, 1177, 5.0),
#  (0, 1225, 4.0),
#  (0, 1409, 5.0),
#  (0, 1551, 5.0),
#  (0, 1643, 5.0),
#  (0, 1679, 4.0),
#  (0, 1680, 3.0),
#  (0, 1690, 5.0),
#  (0, 1762, 4.0),
#  (0, 1876, 5.0),
#  (0, 1960, 4.0),
#  (0, 2037, 4.0),
#  (0, 2153, 5.0),
#  (0, 2191, 4.0),
#  (0, 2213, 5.0),
#  (6, 2258, 4.5),
#  (6, 2323, 4.0),
#  (6, 2419, 3.5),
#  (6, 2518, 3.5),
#  (6, 2542, 4.5),
#  (6, 2786, 2.5),
#  (6, 2825, 4.5),
#  (6, 3090, 2.5),
#  (6, 3158, 3.5),
#  (6, 3199, 1.5),
#  (6, 3217, 3.5),
#  (6, 3260, 3.0),
#  (6, 3493, 2.5),
#  (6, 3667, 0.5),
#  (6, 3719, 2.0),
#  (6, 3730, 5.0),
#  (6, 3808, 4.0),
#  (6, 3891, 3.5),
#  (6, 3994, 4.0),
#  (6, 3997, 4.5),
#  (6, 4105, 4.5),
#  (6, 4313, 3.0),
#  (6, 4404, 3.5),
#  (6, 4453, 3.5),
#  (6, 4464, 3.0),
#  (6, 4474, 4.5),
#  (6, 4484, 0.5),
#  (6, 4491, 1.0),
#  (6, 4539, 4.5),
#  (6, 4648, 2.0),
#  (6, 4782, 4.5),
#  (6, 4783, 4.0),
#  (6, 4784, 4.5),
#  (6, 4980, 4.0),
#  (6, 5069, 2.0),
#  (6, 5137, 3.0),
#  (6, 5253, 4.0),
#  (6, 5257, 1.0),
#  (6, 5312, 4.0),
#  (6, 5537, 2.5),
#  (6, 6007, 0.5),
#  (6, 6042, 2.5),
#  (6, 6065, 2.0),
#  (6, 6137, 5.0),
#  (6, 6138, 1.0),
#  (6, 6167, 1.0),
#  (6, 6268, 1.5),
#  (6, 6269, 1.5),
#  (6, 6285, 4.5),
#  (6, 6311, 5.0),
#  (6, 6427, 3.5),
#  (6, 6493, 4.0),
#  (6, 6619, 1.5),
#  (6, 6633, 4.5),
#  (6, 6804, 4.0),
#  (6, 6834, 4.5),
#  (6, 6929, 5.0),
#  (6, 6983, 1.0),
#  (6, 7048, 4.0),
#  (6, 7049, 3.5),
#  (6, 7073, 1.5),
#  (6, 7075, 5.0),
#  (6, 7097, 3.5),
#  (6, 7122, 4.5),
#  (6, 7308, 5.0),
#  (6, 7369, 1.5),
#  (6, 7371, 1.0),
#  (6, 7372, 5.0),
#  (6, 7374, 4.0),
#  (6, 7421, 2.0),
#  (6, 7546, 3.0),
#  (6, 7951, 1.5),
#  (6, 8129, 4.0),
#  (6, 8162, 4.5),
#  (6, 8163, 4.5),
#  (6, 8236, 3.0),
#  (6, 8241, 3.0),
#  (6, 8274, 3.0),
#  (6, 8315, 3.0),
#  (6, 8385, 4.5),
#  (6, 8449, 1.0),
#  (6, 8528, 3.0),
#  (6, 8618, 4.0),
#  (6, 8850, 3.5),
#  (6, 8855, 4.0),
#  (7, 401, 4.0),
#  (7, 522, 4.0),
#  (7, 659, 5.0),
#  (7, 777, 2.0),
#  (7, 1000, 3.0),
#  (7, 1225, 3.0),
#  (7, 1960, 5.0),
#  (7, 2403, 4.0),
#  (7, 2799, 4.0),
#  (7, 2962, 3.0),
#  (7, 3022, 3.0),
#  (7, 3126, 4.0),
#  (7, 3136, 3.0),
#  (7, 3251, 2.0),
#  (7, 3681, 3.0),
#  (9, 4403, 5.0),
#  (9, 4410, 1.0),
#  (9, 4455, 3.5),
#  (9, 4586, 4.0),
#  (9, 4658, 1.0),
#  (9, 4782, 4.0),
#  (9, 4808, 3.0),
#  (9, 4907, 2.5),
#  (9, 4917, 4.0),
#  (9, 4918, 4.0),
#  (9, 4924, 3.0),
#  (9, 5042, 0.5),
#  (9, 5061, 2.5),
#  (9, 5070, 0.5),
#  (9, 5100, 3.5),
#  (9, 5286, 4.0),
#  (9, 5330, 2.5),
#  (9, 5398, 4.0),
#  (9, 5662, 3.5),
#  (9, 5695, 5.0),
#  (9, 5707, 3.5),
#  (9, 6239, 4.5),
#  (9, 6240, 3.0),
#  (9, 6259, 4.0),
#  (9, 6268, 3.0),
#  (9, 6271, 3.5),
#  (9, 6279, 3.5),
#  (9, 6305, 4.5),
#  (9, 6320, 1.0),
#  (9, 6343, 3.0),
#  (9, 6730, 0.5),
#  (9, 6798, 2.0),
#  (9, 7009, 3.0),
#  (9, 7048, 4.5),
#  (9, 7105, 3.5),
#  (9, 7122, 0.5),
#  (9, 7133, 5.0),
#  (9, 7223, 4.0),
#  (9, 7299, 3.5),
#  (9, 7330, 2.0),
#  (9, 7574, 3.0),
#  (9, 7658, 3.5),
#  (9, 7659, 4.0),
#  (9, 7831, 4.5),
#  (9, 7842, 5.0),
#  (9, 8231, 5.0),
#  (9, 8270, 3.0),
#  (9, 8271, 3.0),
#  (9, 8272, 3.0),
#  (9, 8273, 3.0),
#  (9, 8291, 3.0),
#  (9, 8372, 4.0),
#  (9, 8375, 2.5),
#  (9, 8395, 3.0),
#  (9, 8437, 2.0),
#  (9, 8497, 4.0),
#  (9, 8498, 3.0),
#  (9, 8582, 2.5),
#  (9, 8610, 2.0),
#  (9, 8619, 3.0),
#  (9, 8631, 3.0),
#  (9, 8665, 4.0),
#  (9, 8867, 0.5),
#  (10, 265, 4.0),
#  (10, 418, 5.0),
#  (10, 522, 5.0),
#  ...]

# %% [markdown]
# ### D. Gradient descent

# %%
optim = torch.optim.SGD([Q, P], lr = 0.01)

epochs = 30

for epoch in range(epochs):
    for i, x, rating in value:
        predict = torch.sum(Q[i] * P[x])
        rating = torch.tensor(rating, dtype = torch.float32)

        # loss
        loss = F.mse_loss(predict, rating)

        optim.zero_grad()
        loss.backward()
        optim.step()

    if epoch % 5 == 0:
        print("epoch: {}, loss: {:.6f}" .format(epoch, loss.item()))
# Out:
# epoch: 0, loss: 5.261974
# epoch: 5, loss: 0.491939
# epoch: 10, loss: 0.701293
# epoch: 15, loss: 0.598788
# epoch: 20, loss: 0.547039
# epoch: 25, loss: 0.529228

# %% [markdown]
# ### E. 결과

# %%
y_hat = torch.matmul(Q, P.T)
y_hat = torch.abs(y_hat) # 절대값 적용 안하고 1.0에서 5.0 사이로 적용하는 거랑 결과는 차이 없음

y_hat[y_hat > 5.0]=5.0
y_hat[y_hat < 1.0]=1.0

y_hat = torch.round(y_hat, decimals = 1)
y_hat
# Out:
# tensor([[4.0000, 5.0000, 2.9000,  ..., 3.0000, 4.1000, 1.5000],
#         [3.5000, 4.0000, 1.6000,  ..., 4.7000, 1.9000, 1.2000],
#         [3.0000, 1.0000, 5.0000,  ..., 1.0000, 1.0000, 1.0000],
#         ...,
#         [3.2000, 5.0000, 3.3000,  ..., 1.0000, 2.7000, 1.0000],
#         [2.7000, 3.6000, 2.1000,  ..., 2.1000, 1.8000, 1.4000],
#         [3.9000, 5.0000, 3.8000,  ..., 2.0000, 3.1000, 1.0000]],
#        grad_fn=<RoundBackward1>)

# %% [markdown]
# ### 0.5 단위

# %%
# x.3 ~ x.7 -> x.5로 scaling
y_hat = ((y_hat+0.2)//0.5)*0.5
y_hat

# y_hat2 = torch.round(y_hat)
# y_hat = torch.where(y_hat%0.5!=0, y_hat2, y_hat)
# y_hat
# Out:
# tensor([[4.0000, 5.0000, 3.0000,  ..., 3.0000, 4.0000, 1.5000],
#         [3.5000, 4.0000, 1.5000,  ..., 4.5000, 2.0000, 1.0000],
#         [3.0000, 1.0000, 5.0000,  ..., 1.0000, 1.0000, 1.0000],
#         ...,
#         [3.0000, 5.0000, 3.5000,  ..., 1.0000, 2.5000, 1.0000],
#         [2.5000, 3.5000, 2.0000,  ..., 2.0000, 2.0000, 1.5000],
#         [4.0000, 5.0000, 4.0000,  ..., 2.0000, 3.0000, 1.0000]],
#        grad_fn=<MulBackward0>)

# %%
latent_matrix = pd.DataFrame(y_hat.detach().numpy(),
                            columns = df.columns,
                            index = df.index)
latent_matrix
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              4.0                                      5.0
# 2              3.5                                      4.0
# 3              3.0                                      1.0
# 4              2.0                                      2.5
# 5              1.0                                      3.0
# ...            ...                                      ...
# 606            3.5                                      5.0
# 607            2.5                                      5.0
# 608            3.0                                      5.0
# 609            2.5                                      3.5
# 610            4.0                                      5.0
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          3.0                  2.5
# 2                          1.5                  1.5
# 3                          5.0                  1.0
# 4                          2.0                  2.0
# 5                          1.5                  1.0
# ...                        ...                  ...
# 606                        3.5                  3.5
# 607                        2.5                  3.5
# 608                        3.5                  3.0
# 609                        2.0                  2.5
# 610                        4.0                  3.0
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             2.5                              2.0
# 2                             1.5                              1.0
# 3                             1.0                              3.0
# 4                             1.0                              1.0
# 5                             1.0                              1.0
# ...                           ...                              ...
# 606                           2.5                              1.0
# 607                           3.0                              1.0
# 608                           2.5                              1.0
# 609                           2.0                              1.5
# 610                           2.5                              1.5
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      3.5                   2.5                          5.0
# 2                      3.0                   2.0                          5.0
# 3                      1.0                   5.0                          1.0
# 4                      3.5                   1.5                          5.0
# 5                      3.5                   3.5                          5.0
# ...                    ...                   ...                          ...
# 606                    3.0                   3.0                          4.0
# 607                    2.5                   2.5                          5.0
# 608                    2.0                   3.5                          3.0
# 609                    3.5                   2.0                          4.0
# 610                    3.0                   3.5                          4.0
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                  5.0  ...          1.0           5.0
# 2                                  4.5  ...          2.5           4.5
# 3                                  5.0  ...          4.5           2.5
# 4                                  4.0  ...          3.5           4.0
# 5                                  3.0  ...          1.0           1.5
# ...                                ...  ...          ...           ...
# 606                                3.5  ...          1.5           4.0
# 607                                3.5  ...          1.0           5.0
# 608                                4.0  ...          2.0           3.5
# 609                                1.5  ...          1.0           2.0
# 610                                4.5  ...          1.5           4.5
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 3.5                      1.5
# 2                 1.0                      1.0
# 3                 2.5                      5.0
# 4                 1.0                      2.5
# 5                 4.0                      5.0
# ...               ...                      ...
# 606               2.5                      3.0
# 607               3.0                      1.0
# 608               3.0                      2.5
# 609               2.0                      3.5
# 610               3.0                      3.0
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     4.0
# 2                                                     1.5
# 3                                                     2.5
# 4                                                     3.0
# 5                                                     1.0
# ...                                                   ...
# 606                                                   2.5
# 607                                                   2.5
# 608                                                   3.0
# 609                                                   1.5
# 610                                                   3.5
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   4.0         3.0                             3.0
# 2                   4.0         1.5                             4.5
# 3                   5.0         1.0                             1.0
# 4                   2.5         1.0                             4.0
# 5                   2.5         1.0                             2.5
# ...                 ...         ...                             ...
# 606                 4.0         2.5                             2.0
# 607                 4.0         1.5                             3.0
# 608                 4.0         3.0                             1.0
# 609                 2.0         2.0                             2.0
# 610                 4.5         3.0                             2.0
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        1.5
# 2                         2.0                                        1.0
# 3                         1.0                                        1.0
# 4                         3.0                                        2.0
# 5                         1.5                                        2.0
# ...                       ...                                        ...
# 606                       3.0                                        1.0
# 607                       3.5                                        1.0
# 608                       2.5                                        1.0
# 609                       2.0                                        1.5
# 610                       3.0                                        1.0
#
# [610 rows x 8949 columns]

# %% [markdown]
# ### 1.0 단위
#
# ```Python
# y_hat = torch.matmul(Q, P.T)
# y_hat = torch.abs(y_hat)
#
# y_hat[y_hat > 5.0]=5.0
# y_hat[y_hat < 1.0]=1.0
#
# y_hat = torch.round(y_hat, decimals = 1)
# y_hat = torch.round(y_hat, decimals = 0)
#
# y_hat
#
# latent_matrix = pd.DataFrame(y_hat.detach().numpy(),
#                             columns = df.columns,
#                             index = df.index)
# latent_matrix
# ```

# %% [markdown]
# ## 사용자의 평균 평점으로 대체

# %%
def user_mean_rating(user):
    user_mean = np.round(latent_matrix.iloc[user-1, :].mean(), 1)
    if user_mean%0.5 != 0:
        user_mean = np.round(user_mean, 0)
    return user_mean

# %%
pred_rating = []

for row in range(test.shape[0]):
    x = test.iloc[row, :]['userId']
    y = test.iloc[row, :]['title']
    
    if y in latent_matrix.columns:
        pred_rating.append(latent_matrix[y][x])
        
    else:  
        ## train 데이터에 없는 영화
        mean_rating = user_mean_rating(x)
        pred_rating.append(mean_rating)

# %%
submission_test = pd.DataFrame(columns = ['rId' , 'rating'])
submission_test['rId'] = test['rId']
submission_test['rating'] = pred_rating
submission_test.to_csv('submmision_test.csv', index = False)

# %%
submission_test
# Out:
#          rId  rating
# 0          1     3.0
# 1          2     4.0
# 2          3     3.5
# 3          4     4.0
# 4          5     4.0
# ...      ...     ...
# 20161  20162     4.5
# 20162  20163     3.0
# 20163  20164     3.0
# 20164  20165     4.0
# 20165  20166     2.5
#
# [20166 rows x 2 columns]
